# %%
import pandas as pd
import os

# %%
## try to plot the interpretation probabilities of the data, which requires:
# 1. normalization
# 2. matching the states to utterances
# 3. matching the samples to items (kettle etc)
# 4. categoriziing the s, u pairs
# 5. plotting
# 6. comparing to the extant results
